# %% [markdown]
# # BP神经网络模型

# %%
import numpy as np
import math
import random
import string
import matplotlib as mpl
import matplotlib.pyplot as plt
 
#random.seed(0)  #当我们设置相同的seed，每次生成的随机数相同。如果不设置seed，则每次会生成不同的随机数
                #参考https://blog.csdn.net/jiangjiang_jian/article/details/79031788

#生成区间[a,b]内的随机数
def random_number(a,b):
    return (b-a)*random.random()+a
 
#生成一个矩阵，大小为m*n,并且设置默认零矩阵
def makematrix(m, n, fill=0.0):
    a = []
    for i in range(m):
        a.append([fill]*n)
    return a
 
#函数sigmoid(),这里采用tanh，因为看起来要比标准的sigmoid函数好看
def sigmoid(x):
    return math.tanh(x)
 
#函数sigmoid的派生函数
def derived_sigmoid(x):
    return 1.0 - x**2
 
#构造三层BP网络架构
class BPNN:
    def __init__(self, num_in, num_hidden, num_out):
        #输入层，隐藏层，输出层的节点数
        self.num_in = num_in + 1  #增加一个偏置结点
        self.num_hidden = num_hidden + 1   #增加一个偏置结点
        self.num_out = num_out
        
        #激活神经网络的所有节点（向量）
        self.active_in = [1.0]*self.num_in
        self.active_hidden = [1.0]*self.num_hidden
        self.active_out = [1.0]*self.num_out
        
        #创建权重矩阵
        self.wight_in = makematrix(self.num_in, self.num_hidden)
        self.wight_out = makematrix(self.num_hidden, self.num_out)
        
        #对权值矩阵赋初值
        for i in range(self.num_in):
            for j in range(self.num_hidden):
                self.wight_in[i][j] = random_number(-0.2, 0.2)
        for i in range(self.num_hidden):
            for j in range(self.num_out):
                self.wight_out[i][j] = random_number(-0.2, 0.2)
    
        #最后建立动量因子（矩阵）
        self.ci = makematrix(self.num_in, self.num_hidden)
        self.co = makematrix(self.num_hidden, self.num_out)        
        
    #信号正向传播
    def update(self, inputs):
        if len(inputs) != self.num_in-1:
            raise ValueError('与输入层节点数不符')
            
        #数据输入输入层
        for i in range(self.num_in - 1):
            #self.active_in[i] = sigmoid(inputs[i])  #或者先在输入层进行数据处理
            self.active_in[i] = inputs[i]  #active_in[]是输入数据的矩阵
            
        #数据在隐藏层的处理
        for i in range(self.num_hidden - 1):
            sum = 0.0
            for j in range(self.num_in):
                sum = sum + self.active_in[i] * self.wight_in[j][i]
            self.active_hidden[i] = sigmoid(sum)   #active_hidden[]是处理完输入数据之后存储，作为输出层的输入数据
            
        #数据在输出层的处理
        for i in range(self.num_out):
            sum = 0.0
            for j in range(self.num_hidden):
                sum = sum + self.active_hidden[j]*self.wight_out[j][i]
            self.active_out[i] = sigmoid(sum)   #与上同理
            
        return self.active_out[:]
    
    #误差反向传播
    def errorbackpropagate(self, targets, lr, m):   #lr是学习率， m是动量因子
        if len(targets) != self.num_out:
            raise ValueError('与输出层节点数不符！')
            
        #首先计算输出层的误差
        out_deltas = [0.0]*self.num_out
        for i in range(self.num_out):
            error = targets[i] - self.active_out[i]
            out_deltas[i] = derived_sigmoid(self.active_out[i])*error
        
        #然后计算隐藏层误差
        hidden_deltas = [0.0]*self.num_hidden
        for i in range(self.num_hidden):
            error = 0.0
            for j in range(self.num_out):
                error = error + out_deltas[j]* self.wight_out[i][j]
            hidden_deltas[i] = derived_sigmoid(self.active_hidden[i])*error
        
        #首先更新输出层权值
        for i in range(self.num_hidden):
            for j in range(self.num_out):
                change = out_deltas[j]*self.active_hidden[i]
                self.wight_out[i][j] = self.wight_out[i][j] + lr*change + m*self.co[i][j]
                self.co[i][j] = change
                
        #然后更新输入层权值
        for i in range(self.num_in):
            for i in range(self.num_hidden):
                change = hidden_deltas[j]*self.active_in[i]
                self.wight_in[i][j] = self.wight_in[i][j] + lr*change + m* self.ci[i][j]
                self.ci[i][j] = change
                
        #计算总误差
        error = 0.0
        for i in range(len(targets)):
            error = error + 0.5*(targets[i] - self.active_out[i])**2
        return error
 
    #测试
    def test(self, patterns):
        for i in patterns:
            print(i[0], '->', self.update(i[0]))
    #权重
    def weights(self):
        print("输入层权重")
        for i in range(self.num_in):
            print(self.wight_in[i])
        print("输出层权重")
        for i in range(self.num_hidden):
            print(self.wight_out[i])
            
    def train(self, pattern, itera=100000, lr = 0.1, m=0.1):
        for i in range(itera):
            error = 0.0
            for j in pattern:
                inputs = j[0]
                targets = j[1]
                self.update(inputs)
                error = error + self.errorbackpropagate(targets, lr, m)
            if i % 100 == 0:
                print('误差 %-.5f' % error)
    
#实例
def demo():
    patt = [
            [[1,2,5],[0]],
            [[1,3,4],[1]],
            [[1,6,2],[1]],
            [[1,5,1],[0]],
            [[1,8,4],[1]]
            ]
    #创建神经网络，3个输入节点，3个隐藏层节点，1个输出层节点
    n = BPNN(3, 3, 1)
    #训练神经网络
    n.train(patt)
    #测试神经网络
    n.test(patt)
    #查阅权重值
    n.weights()

demo()
# Out:
# 误差 1.46478
# 误差 0.50013
# 误差 0.48193
# 误差 0.46873
# 误差 0.45596
# 误差 0.44333
# 误差 0.43094
# 误差 0.41892
# 误差 0.40734
# 误差 0.39623
# 误差 0.38562
# 误差 0.37550
# 误差 0.36587
# 误差 0.35672
# 误差 0.34803
# 误差 0.33978
# 误差 0.33194
# 误差 0.32451
# 误差 0.31745
# 误差 0.31075
# 误差 0.30438
# 误差 0.29834
# 误差 0.29259
# 误差 0.28713
# 误差 0.28192
# 误差 0.27697
# 误差 0.27225
# 误差 0.26775
# 误差 0.26345
# 误差 0.25934
# 误差 0.25541
# 误差 0.25165
# 误差 0.24805
# 误差 0.24459
# 误差 0.24127
# 误差 0.23809
# 误差 0.23502
# 误差 0.23207
# 误差 0.22923
# 误差 0.22649
# 误差 0.22384
# 误差 0.22128
# 误差 0.21881
# 误差 0.21642
# 误差 0.21410
# 误差 0.21186
# 误差 0.20968
# 误差 0.20757
# 误差 0.20551
# 误差 0.20351
# 误差 0.20157
# 误差 0.19968
# 误差 0.19784
# 误差 0.19604
# 误差 0.19429
# 误差 0.19258
# 误差 0.19091
# 误差 0.18928
# 误差 0.18768
# 误差 0.18612
# 误差 0.18460
# 误差 0.18310
# 误差 0.18164
# 误差 0.18021
# 误差 0.17880
# 误差 0.17742
# 误差 0.17607
# 误差 0.17474
# 误差 0.17344
# 误差 0.17216
# 误差 0.17090
# 误差 0.16966
# 误差 0.16844
# 误差 0.16725
# 误差 0.16607
# 误差 0.16491
# 误差 0.16377
# 误差 0.16265
# 误差 0.16154
# 误差 0.16045
# 误差 0.15938
# 误差 0.15832
# 误差 0.15727
# 误差 0.15624
# 误差 0.15523
# 误差 0.15423
# 误差 0.15324
# 误差 0.15226
# 误差 0.15130
# 误差 0.15035
# 误差 0.14941
# 误差 0.14848
# 误差 0.14756
# 误差 0.14666
# 误差 0.14576
# 误差 0.14488
# 误差 0.14401
# 误差 0.14314
# 误差 0.14229
# 误差 0.14145
# 误差 0.14061
# 误差 0.13978
# 误差 0.13897
# 误差 0.13816
# 误差 0.13736
# 误差 0.13657
# 误差 0.13579
# 误差 0.13501
# 误差 0.13424
# 误差 0.13349
# 误差 0.13273
# 误差 0.13199
# 误差 0.13125
# 误差 0.13052
# 误差 0.12980
# 误差 0.12909
# 误差 0.12838
# 误差 0.12768
# 误差 0.12698
# 误差 0.12629
# 误差 0.12561
# 误差 0.12494
# 误差 0.12427
# 误差 0.12360
# 误差 0.12294
# 误差 0.12229
# 误差 0.12165
# 误差 0.12101
# 误差 0.12037
# 误差 0.11974
# 误差 0.11912
# 误差 0.11850
# 误差 0.11789
# 误差 0.11728
# 误差 0.11668
# 误差 0.11608
# 误差 0.11549
# 误差 0.11490
# 误差 0.11432
# 误差 0.11374
# 误差 0.11317
# 误差 0.11260
# 误差 0.11204
# 误差 0.11148
# 误差 0.11092
# 误差 0.11037
# 误差 0.10983
# 误差 0.10929
# 误差 0.10875
# 误差 0.10822
# 误差 0.10769
# 误差 0.10717
# 误差 0.10665
# 误差 0.10613
# 误差 0.10562
# 误差 0.10511
# 误差 0.10461
# 误差 0.10411
# 误差 0.10361
# 误差 0.10312
# 误差 0.10263
# 误差 0.10214
# 误差 0.10166
# 误差 0.10119
# 误差 0.10071
# 误差 0.10024
# 误差 0.09977
# 误差 0.09931
# 误差 0.09885
# 误差 0.09839
# 误差 0.09794
# 误差 0.09749
# 误差 0.09704
# 误差 0.09660
# 误差 0.09616
# 误差 0.09572
# 误差 0.09529
# 误差 0.09486
# 误差 0.09443
# 误差 0.09400
# 误差 0.09358
# 误差 0.09316
# 误差 0.09275
# 误差 0.09234
# 误差 0.09193
# 误差 0.09152
# 误差 0.09112
# 误差 0.09071
# 误差 0.09032
# 误差 0.08992
# 误差 0.08953
# 误差 0.08914
# 误差 0.08875
# 误差 0.08837
# 误差 0.08798
# 误差 0.08760
# 误差 0.08723
# 误差 0.08685
# 误差 0.08648
# 误差 0.08611
# 误差 0.08575
# 误差 0.08538
# 误差 0.08502
# 误差 0.08466
# 误差 0.08430
# 误差 0.08395
# 误差 0.08360
# 误差 0.08325
# 误差 0.08290
# 误差 0.08255
# 误差 0.08221
# 误差 0.08187
# 误差 0.08153
# 误差 0.08120
# 误差 0.08086
# 误差 0.08053
# 误差 0.08020
# 误差 0.07987
# 误差 0.07955
# 误差 0.07923
# 误差 0.07890
# 误差 0.07859
# 误差 0.07827
# 误差 0.07795
# 误差 0.07764
# 误差 0.07733
# 误差 0.07702
# 误差 0.07671
# 误差 0.07641
# 误差 0.07611
# 误差 0.07581
# 误差 0.07551
# 误差 0.07521
# 误差 0.07491
# 误差 0.07462
# 误差 0.07433
# 误差 0.07404
# 误差 0.07375
# 误差 0.07346
# 误差 0.07318
# 误差 0.07290
# 误差 0.07262
# 误差 0.07234
# 误差 0.07206
# 误差 0.07178
# 误差 0.07151
# 误差 0.07124
# 误差 0.07097
# 误差 0.07070
# 误差 0.07043
# 误差 0.07017
# 误差 0.06990
# 误差 0.06964
# 误差 0.06938
# 误差 0.06912
# 误差 0.06886
# 误差 0.06860
# 误差 0.06835
# 误差 0.06810
# 误差 0.06785
# 误差 0.06759
# 误差 0.06735
# 误差 0.06710
# 误差 0.06685
# 误差 0.06661
# 误差 0.06637
# 误差 0.06613
# 误差 0.06589
# 误差 0.06565
# 误差 0.06541
# 误差 0.06517
# 误差 0.06494
# 误差 0.06471
# 误差 0.06448
# 误差 0.06424
# 误差 0.06402
# 误差 0.06379
# 误差 0.06356
# 误差 0.06334
# 误差 0.06311
# 误差 0.06289
# 误差 0.06267
# 误差 0.06245
# 误差 0.06223
# 误差 0.06201
# 误差 0.06180
# 误差 0.06158
# 误差 0.06137
# 误差 0.06116
# 误差 0.06095
# 误差 0.06074
# 误差 0.06053
# 误差 0.06032
# 误差 0.06011
# 误差 0.05991
# 误差 0.05970
# 误差 0.05950
# 误差 0.05930
# 误差 0.05910
# 误差 0.05890
# 误差 0.05870
# 误差 0.05850
# 误差 0.05831
# 误差 0.05811
# 误差 0.05792
# 误差 0.05772
# 误差 0.05753
# 误差 0.05734
# 误差 0.05715
# 误差 0.05696
# 误差 0.05677
# 误差 0.05659
# 误差 0.05640
# 误差 0.05621
# 误差 0.05603
# 误差 0.05585
# 误差 0.05567
# 误差 0.05549
# 误差 0.05531
# 误差 0.05513
# 误差 0.05495
# 误差 0.05477
# 误差 0.05459
# 误差 0.05442
# 误差 0.05425
# 误差 0.05407
# 误差 0.05390
# 误差 0.05373
# 误差 0.05356
# 误差 0.05339
# 误差 0.05322
# 误差 0.05305
# 误差 0.05288
# 误差 0.05272
# 误差 0.05255
# 误差 0.05239
# 误差 0.05222
# 误差 0.05206
# 误差 0.05190
# 误差 0.05174
# 误差 0.05158
# 误差 0.05142
# 误差 0.05126
# 误差 0.05110
# 误差 0.05095
# 误差 0.05079
# 误差 0.05063
# 误差 0.05048
# 误差 0.05033
# 误差 0.05017
# 误差 0.05002
# 误差 0.04987
# 误差 0.04972
# 误差 0.04957
# 误差 0.04942
# 误差 0.04927
# 误差 0.04912
# 误差 0.04898
# 误差 0.04883
# 误差 0.04868
# 误差 0.04854
# 误差 0.04840
# 误差 0.04825
# 误差 0.04811
# 误差 0.04797
# 误差 0.04783
# 误差 0.04769
# 误差 0.04755
# 误差 0.04741
# 误差 0.04727
# 误差 0.04713
# 误差 0.04699
# 误差 0.04686
# 误差 0.04672
# 误差 0.04659
# 误差 0.04645
# 误差 0.04632
# 误差 0.04618
# 误差 0.04605
# 误差 0.04592
# 误差 0.04579
# 误差 0.04566
# 误差 0.04553
# 误差 0.04540
# 误差 0.04527
# 误差 0.04514
# 误差 0.04502
# 误差 0.04489
# 误差 0.04476
# 误差 0.04464
# 误差 0.04451
# 误差 0.04439
# 误差 0.04426
# 误差 0.04414
# 误差 0.04402
# 误差 0.04389
# 误差 0.04377
# 误差 0.04365
# 误差 0.04353
# 误差 0.04341
# 误差 0.04329
# 误差 0.04317
# 误差 0.04306
# 误差 0.04294
# 误差 0.04282
# 误差 0.04270
# 误差 0.04259
# 误差 0.04247
# 误差 0.04236
# 误差 0.04224
# 误差 0.04213
# 误差 0.04202
# 误差 0.04190
# 误差 0.04179
# 误差 0.04168
# 误差 0.04157
# 误差 0.04146
# 误差 0.04135
# 误差 0.04124
# 误差 0.04113
# 误差 0.04102
# 误差 0.04091
# 误差 0.04080
# 误差 0.04069
# 误差 0.04059
# 误差 0.04048
# 误差 0.04038
# 误差 0.04027
# 误差 0.04016
# 误差 0.04006
# 误差 0.03996
# 误差 0.03985
# 误差 0.03975
# 误差 0.03965
# 误差 0.03954
# 误差 0.03944
# 误差 0.03934
# 误差 0.03924
# 误差 0.03914
# 误差 0.03904
# 误差 0.03894
# 误差 0.03884
# 误差 0.03874
# 误差 0.03864
# 误差 0.03855
# 误差 0.03845
# 误差 0.03835
# 误差 0.03826
# 误差 0.03816
# 误差 0.03806
# 误差 0.03797
# 误差 0.03787
# 误差 0.03778
# 误差 0.03768
# 误差 0.03759
# 误差 0.03750
# 误差 0.03740
# 误差 0.03731
# 误差 0.03722
# 误差 0.03713
# 误差 0.03704
# 误差 0.03695
# 误差 0.03685
# 误差 0.03676
# 误差 0.03667
# 误差 0.03659
# 误差 0.03650
# 误差 0.03641
# 误差 0.03632
# 误差 0.03623
# 误差 0.03614
# 误差 0.03606
# 误差 0.03597
# 误差 0.03588
# 误差 0.03580
# 误差 0.03571
# 误差 0.03563
# 误差 0.03554
# 误差 0.03546
# 误差 0.03537
# 误差 0.03529
# 误差 0.03520
# 误差 0.03512
# 误差 0.03504
# 误差 0.03495
# 误差 0.03487
# 误差 0.03479
# 误差 0.03471
# 误差 0.03463
# 误差 0.03455
# 误差 0.03447
# 误差 0.03439
# 误差 0.03431
# 误差 0.03423
# 误差 0.03415
# 误差 0.03407
# 误差 0.03399
# 误差 0.03391
# 误差 0.03383
# 误差 0.03375
# 误差 0.03368
# 误差 0.03360
# 误差 0.03352
# 误差 0.03345
# 误差 0.03337
# 误差 0.03329
# 误差 0.03322
# 误差 0.03314
# 误差 0.03307
# 误差 0.03299
# 误差 0.03292
# 误差 0.03284
# 误差 0.03277
# 误差 0.03270
# 误差 0.03262
# 误差 0.03255
# 误差 0.03248
# 误差 0.03240
# 误差 0.03233
# 误差 0.03226
# 误差 0.03219
# 误差 0.03212
# 误差 0.03205
# 误差 0.03198
# 误差 0.03191
# 误差 0.03184
# 误差 0.03177
# 误差 0.03170
# 误差 0.03163
# 误差 0.03156
# 误差 0.03149
# 误差 0.03142
# 误差 0.03135
# 误差 0.03128
# 误差 0.03121
# 误差 0.03115
# 误差 0.03108
# 误差 0.03101
# 误差 0.03095
# 误差 0.03088
# 误差 0.03081
# 误差 0.03075
# 误差 0.03068
# 误差 0.03061
# 误差 0.03055
# 误差 0.03048
# 误差 0.03042
# 误差 0.03035
# 误差 0.03029
# 误差 0.03023
# 误差 0.03016
# 误差 0.03010
# 误差 0.03004
# 误差 0.02997
# 误差 0.02991
# 误差 0.02985
# 误差 0.02978
# 误差 0.02972
# 误差 0.02966
# 误差 0.02960
# 误差 0.02954
# 误差 0.02947
# 误差 0.02941
# 误差 0.02935
# 误差 0.02929
# 误差 0.02923
# 误差 0.02917
# 误差 0.02911
# 误差 0.02905
# 误差 0.02899
# 误差 0.02893
# 误差 0.02887
# 误差 0.02881
# 误差 0.02875
# 误差 0.02870
# 误差 0.02864
# 误差 0.02858
# 误差 0.02852
# 误差 0.02846
# 误差 0.02841
# 误差 0.02835
# 误差 0.02829
# 误差 0.02824
# 误差 0.02818
# 误差 0.02812
# 误差 0.02807
# 误差 0.02801
# 误差 0.02795
# 误差 0.02790
# 误差 0.02784
# 误差 0.02779
# 误差 0.02773
# 误差 0.02768
# 误差 0.02762
# 误差 0.02757
# 误差 0.02751
# 误差 0.02746
# 误差 0.02740
# 误差 0.02735
# 误差 0.02730
# 误差 0.02724
# 误差 0.02719
# 误差 0.02714
# 误差 0.02708
# 误差 0.02703
# 误差 0.02698
# 误差 0.02693
# 误差 0.02687
# 误差 0.02682
# 误差 0.02677
# 误差 0.02672
# 误差 0.02667
# 误差 0.02662
# 误差 0.02657
# 误差 0.02651
# 误差 0.02646
# 误差 0.02641
# 误差 0.02636
# 误差 0.02631
# 误差 0.02626
# 误差 0.02621
# 误差 0.02616
# 误差 0.02611
# 误差 0.02606
# 误差 0.02601
# 误差 0.02597
# 误差 0.02592
# 误差 0.02587
# 误差 0.02582
# 误差 0.02577
# 误差 0.02572
# 误差 0.02567
# 误差 0.02563
# 误差 0.02558
# 误差 0.02553
# 误差 0.02548
# 误差 0.02544
# 误差 0.02539
# 误差 0.02534
# 误差 0.02530
# 误差 0.02525
# 误差 0.02520
# 误差 0.02516
# 误差 0.02511
# 误差 0.02506
# 误差 0.02502
# 误差 0.02497
# 误差 0.02493
# 误差 0.02488
# 误差 0.02483
# 误差 0.02479
# 误差 0.02474
# 误差 0.02470
# 误差 0.02465
# 误差 0.02461
# 误差 0.02457
# 误差 0.02452
# 误差 0.02448
# 误差 0.02443
# 误差 0.02439
# 误差 0.02435
# 误差 0.02430
# 误差 0.02426
# 误差 0.02422
# 误差 0.02417
# 误差 0.02413
# 误差 0.02409
# 误差 0.02404
# 误差 0.02400
# 误差 0.02396
# 误差 0.02392
# 误差 0.02387
# 误差 0.02383
# 误差 0.02379
# 误差 0.02375
# 误差 0.02371
# 误差 0.02366
# 误差 0.02362
# 误差 0.02358
# 误差 0.02354
# 误差 0.02350
# 误差 0.02346
# 误差 0.02342
# 误差 0.02338
# 误差 0.02334
# 误差 0.02330
# 误差 0.02325
# 误差 0.02321
# 误差 0.02317
# 误差 0.02313
# 误差 0.02309
# 误差 0.02306
# 误差 0.02302
# 误差 0.02298
# 误差 0.02294
# 误差 0.02290
# 误差 0.02286
# 误差 0.02282
# 误差 0.02278
# 误差 0.02274
# 误差 0.02270
# 误差 0.02266
# 误差 0.02263
# 误差 0.02259
# 误差 0.02255
# 误差 0.02251
# 误差 0.02247
# 误差 0.02244
# 误差 0.02240
# 误差 0.02236
# 误差 0.02232
# 误差 0.02229
# 误差 0.02225
# 误差 0.02221
# 误差 0.02217
# 误差 0.02214
# 误差 0.02210
# 误差 0.02206
# 误差 0.02203
# 误差 0.02199
# 误差 0.02195
# 误差 0.02192
# 误差 0.02188
# 误差 0.02185
# 误差 0.02181
# 误差 0.02177
# 误差 0.02174
# 误差 0.02170
# 误差 0.02167
# 误差 0.02163
# 误差 0.02160
# 误差 0.02156
# 误差 0.02153
# 误差 0.02149
# 误差 0.02146
# 误差 0.02142
# 误差 0.02139
# 误差 0.02135
# 误差 0.02132
# 误差 0.02128
# 误差 0.02125
# 误差 0.02121
# 误差 0.02118
# 误差 0.02115
# 误差 0.02111
# 误差 0.02108
# 误差 0.02105
# 误差 0.02101
# 误差 0.02098
# 误差 0.02094
# 误差 0.02091
# 误差 0.02088
# 误差 0.02084
# 误差 0.02081
# 误差 0.02078
# 误差 0.02075
# 误差 0.02071
# 误差 0.02068
# 误差 0.02065
# 误差 0.02062
# 误差 0.02058
# 误差 0.02055
# 误差 0.02052
# 误差 0.02049
# 误差 0.02045
# 误差 0.02042
# 误差 0.02039
# 误差 0.02036
# 误差 0.02033
# 误差 0.02030
# 误差 0.02026
# 误差 0.02023
# 误差 0.02020
# 误差 0.02017
# 误差 0.02014
# 误差 0.02011
# 误差 0.02008
# 误差 0.02005
# 误差 0.02002
# 误差 0.01998
# 误差 0.01995
# 误差 0.01992
# 误差 0.01989
# 误差 0.01986
# 误差 0.01983
# 误差 0.01980
# 误差 0.01977
# 误差 0.01974
# 误差 0.01971
# 误差 0.01968
# 误差 0.01965
# 误差 0.01962
# 误差 0.01959
# 误差 0.01956
# 误差 0.01953
# 误差 0.01950
# 误差 0.01948
# 误差 0.01945
# 误差 0.01942
# 误差 0.01939
# 误差 0.01936
# 误差 0.01933
# 误差 0.01930
# 误差 0.01927
# 误差 0.01924
# 误差 0.01921
# 误差 0.01919
# 误差 0.01916
# 误差 0.01913
# 误差 0.01910
# 误差 0.01907
# 误差 0.01904
# 误差 0.01902
# 误差 0.01899
# 误差 0.01896
# 误差 0.01893
# 误差 0.01891
# 误差 0.01888
# 误差 0.01885
# 误差 0.01882
# 误差 0.01879
# 误差 0.01877
# 误差 0.01874
# 误差 0.01871
# 误差 0.01869
# 误差 0.01866
# 误差 0.01863
# 误差 0.01860
# 误差 0.01858
# 误差 0.01855
# 误差 0.01852
# 误差 0.01850
# 误差 0.01847
# 误差 0.01844
# 误差 0.01842
# 误差 0.01839
# 误差 0.01836
# 误差 0.01834
# 误差 0.01831
# 误差 0.01829
# 误差 0.01826
# 误差 0.01823
# 误差 0.01821
# 误差 0.01818
# 误差 0.01816
# 误差 0.01813
# 误差 0.01811
# 误差 0.01808
# 误差 0.01805
# 误差 0.01803
# 误差 0.01800
# 误差 0.01798
# 误差 0.01795
# 误差 0.01793
# 误差 0.01790
# 误差 0.01788
# 误差 0.01785
# 误差 0.01783
# 误差 0.01780
# 误差 0.01778
# 误差 0.01775
# 误差 0.01773
# 误差 0.01770
# 误差 0.01768
# 误差 0.01765
# 误差 0.01763
# 误差 0.01761
# 误差 0.01758
# 误差 0.01756
# 误差 0.01753
# 误差 0.01751
# 误差 0.01748
# 误差 0.01746
# 误差 0.01744
# 误差 0.01741
# 误差 0.01739
# 误差 0.01736
# 误差 0.01734
# 误差 0.01732
# 误差 0.01729
# 误差 0.01727
# 误差 0.01725
# 误差 0.01722
# 误差 0.01720
# 误差 0.01718
# 误差 0.01715
# 误差 0.01713
# 误差 0.01711
# 误差 0.01708
# 误差 0.01706
# 误差 0.01704
# 误差 0.01701
# 误差 0.01699
# 误差 0.01697
# 误差 0.01695
# 误差 0.01692
# 误差 0.01690
# 误差 0.01688
# 误差 0.01686
# 误差 0.01683
# 误差 0.01681
# 误差 0.01679
# 误差 0.01677
# 误差 0.01674
# 误差 0.01672
# 误差 0.01670
# 误差 0.01668
# 误差 0.01666
# 误差 0.01663
# 误差 0.01661
# 误差 0.01659
# 误差 0.01657
# 误差 0.01655
# 误差 0.01652
# 误差 0.01650
# 误差 0.01648
# 误差 0.01646
# 误差 0.01644
# 误差 0.01642
# 误差 0.01639
# 误差 0.01637
# 误差 0.01635
# 误差 0.01633
# 误差 0.01631
# 误差 0.01629
# 误差 0.01627
# 误差 0.01625
# 误差 0.01623
# 误差 0.01620
# 误差 0.01618
# 误差 0.01616
# 误差 0.01614
# 误差 0.01612
# 误差 0.01610
# 误差 0.01608
# 误差 0.01606
# 误差 0.01604
# 误差 0.01602
# 误差 0.01600
# 误差 0.01598
# 误差 0.01596
# 误差 0.01594
# 误差 0.01592
# 误差 0.01590
# 误差 0.01588
# 误差 0.01585
# 误差 0.01583
# 误差 0.01581
# 误差 0.01579
# 误差 0.01577
# 误差 0.01575
# 误差 0.01574
# 误差 0.01572
# 误差 0.01570
# 误差 0.01568
# 误差 0.01566
# 误差 0.01564
# 误差 0.01562
# 误差 0.01560
# 误差 0.01558
# 误差 0.01556
# 误差 0.01554
# 误差 0.01552
# 误差 0.01550
# 误差 0.01548
# 误差 0.01546
# 误差 0.01544
# 误差 0.01542
# 误差 0.01540
# 误差 0.01538
# 误差 0.01537
# 误差 0.01535
# 误差 0.01533
# 误差 0.01531
# 误差 0.01529
# 误差 0.01527
# 误差 0.01525
# 误差 0.01523
# 误差 0.01522
# 误差 0.01520
# 误差 0.01518
# 误差 0.01516
# 误差 0.01514
# 误差 0.01512
# 误差 0.01510
# 误差 0.01509
# 误差 0.01507
# 误差 0.01505
# 误差 0.01503
# 误差 0.01501
# 误差 0.01499
# 误差 0.01498
# 误差 0.01496
# 误差 0.01494
# 误差 0.01492
# 误差 0.01490
# 误差 0.01489
# 误差 0.01487
# 误差 0.01485
# 误差 0.01483
# [1, 2, 5] -> [0.03432805218680784]
# [1, 3, 4] -> [0.8334367086882403]
# [1, 6, 2] -> [0.9998511639566586]
# [1, 5, 1] -> [0.012857967722412862]
# [1, 8, 4] -> [0.9999999999909337]
# 输入层权重
# [0.010357067131718516, -0.04030533455718607, 0.1989566866693941, -0.1796693231888317]
# [0.1876330518699227, -0.07496406094062272, -0.0705397866609265, -0.08761517416962117]
# [-0.19591904020735232, 0.08925505440967829, -0.18299681633579762, 0.14457619944460604]
# [-0.002071078794288915, -0.10695054628682908, 0.01070944777088978, 0.1898922890726883]
# 输出层权重
# [-1.2581940819503722e-17]
# [-29.064165611871196]
# [-54.471904459769874]
# [-19.278021673869695]
